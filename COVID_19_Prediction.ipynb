# %% [markdown]
# # 1) IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) CLONING DATASET

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319
# Receiving objects: 100% (2319/2319), 1.31 GiB | 42.37 MiB/s, done.
# Checking out files: 100% (2296/2296), done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES : 
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(336).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (25).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(565).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (18).jpeg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(54).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(51).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(307).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(143).jpg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1027).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1257).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(272).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(294).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(351).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(164).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(952).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(790).jpg']

# %% [markdown]
# # 4) DATA PREPROCESSING AND AUGMENTATION

# %%
# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150), 
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150), 
                                                      subset = "validation", 
                                                      batch_size = 32, 
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150), 
                                               batch_size = 32, 
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  dropout (Dropout)           (None, 75, 75, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 256)               22429952
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 22,483,905
# Trainable params: 22,483,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6) COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator, 
                    epochs = 35, 
                    validation_data = validation_generator)
# Out:
# Epoch 1/35
# 46/46 [==============================] - 59s 1s/step - loss: 0.9077 - accuracy: 0.7405 - val_loss: 0.3647 - val_accuracy: 0.8591
# Epoch 2/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.2498 - accuracy: 0.9034 - val_loss: 0.2589 - val_accuracy: 0.9061
# Epoch 3/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1494 - accuracy: 0.9476 - val_loss: 0.1006 - val_accuracy: 0.9724
# Epoch 4/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1317 - accuracy: 0.9531 - val_loss: 0.1193 - val_accuracy: 0.9558
# Epoch 5/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1414 - accuracy: 0.9469 - val_loss: 0.1089 - val_accuracy: 0.9751
# Epoch 6/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1064 - accuracy: 0.9627 - val_loss: 0.1153 - val_accuracy: 0.9696
# Epoch 7/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1019 - accuracy: 0.9627 - val_loss: 0.0769 - val_accuracy: 0.9779
# Epoch 8/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0890 - accuracy: 0.9703 - val_loss: 0.0857 - val_accuracy: 0.9669
# Epoch 9/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1234 - accuracy: 0.9586 - val_loss: 0.1243 - val_accuracy: 0.9530
# Epoch 10/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0938 - accuracy: 0.9648 - val_loss: 0.0996 - val_accuracy: 0.9586
# Epoch 11/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1277 - accuracy: 0.9545 - val_loss: 0.1160 - val_accuracy: 0.9586
# Epoch 12/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.1356 - accuracy: 0.9565 - val_loss: 0.1583 - val_accuracy: 0.9503
# Epoch 13/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.1010 - accuracy: 0.9593 - val_loss: 0.0915 - val_accuracy: 0.9724
# Epoch 14/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0986 - accuracy: 0.9669 - val_loss: 0.0719 - val_accuracy: 0.9751
# Epoch 15/35
# 46/46 [==============================] - 49s 1s/step - loss: 0.0979 - accuracy: 0.9669 - val_loss: 0.1031 - val_accuracy: 0.9641
# Epoch 16/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0830 - accuracy: 0.9758 - val_loss: 0.0849 - val_accuracy: 0.9669
# Epoch 17/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0945 - accuracy: 0.9683 - val_loss: 0.0780 - val_accuracy: 0.9779
# Epoch 18/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0682 - accuracy: 0.9752 - val_loss: 0.0622 - val_accuracy: 0.9779
# Epoch 19/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0767 - accuracy: 0.9758 - val_loss: 0.0759 - val_accuracy: 0.9696
# Epoch 20/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.0587 - accuracy: 0.9765 - val_loss: 0.0788 - val_accuracy: 0.9751
# Epoch 21/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0678 - accuracy: 0.9793 - val_loss: 0.0776 - val_accuracy: 0.9724
# Epoch 22/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0525 - accuracy: 0.9827 - val_loss: 0.0874 - val_accuracy: 0.9751
# Epoch 23/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0606 - accuracy: 0.9814 - val_loss: 0.0796 - val_accuracy: 0.9751
# Epoch 24/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0548 - accuracy: 0.9800 - val_loss: 0.0670 - val_accuracy: 0.9779
# Epoch 25/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0611 - accuracy: 0.9821 - val_loss: 0.0546 - val_accuracy: 0.9862
# Epoch 26/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0605 - accuracy: 0.9772 - val_loss: 0.0658 - val_accuracy: 0.9834
# Epoch 27/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0524 - accuracy: 0.9821 - val_loss: 0.0516 - val_accuracy: 0.9945
# Epoch 28/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0629 - accuracy: 0.9765 - val_loss: 0.0686 - val_accuracy: 0.9724
# Epoch 29/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0461 - accuracy: 0.9841 - val_loss: 0.0649 - val_accuracy: 0.9751
# Epoch 30/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0550 - accuracy: 0.9786 - val_loss: 0.0506 - val_accuracy: 0.9807
# Epoch 31/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0555 - accuracy: 0.9841 - val_loss: 0.0566 - val_accuracy: 0.9862
# Epoch 32/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.0565 - val_accuracy: 0.9807
# Epoch 33/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0691 - accuracy: 0.9772 - val_loss: 0.0641 - val_accuracy: 0.9696
# Epoch 34/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0636 - accuracy: 0.9758 - val_loss: 0.0810 - val_accuracy: 0.9696
# Epoch 35/35
# 46/46 [==============================] - 46s 998ms/step - loss: 0.0673 - accuracy: 0.9752 - val_loss: 0.0678 - val_accuracy: 0.9834

# %% [markdown]
# # 7) PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 [==============================] - 10s 620ms/step - loss: 0.0626 - accuracy: 0.9752
# Test Set Loss :  0.0625695213675499
# Test Set Accuracy :  0.9752066135406494

# %% [markdown]
# # 9) PREDICTION ON NEW DATA (UPLOAD FILES)

# %%
model.save("model.h5")
